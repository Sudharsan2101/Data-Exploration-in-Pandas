# %% [markdown]
# ### DATA EXPLORATION USING PANDAS

# %%
import pandas as pd

# %%
data=pd.read_csv("D:/Carsdataset.csv")

# %% [markdown]
# ##### ABOUT DATA SET
# This dataset was derived from https://www.cardekho.com/. The dataset consists specifications list as we all rating only for new cars.
# ##### Dataset Description
# This dataset consists of 16 features on a total of 203 car choices available in India.

# %%
data
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %% [markdown]
# ##### This dataset contains Complete collection of Cars available to buy in India with their specs.

# %%
data.head()
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
#
#    body_type  rating  starting_price  ending_price  max_torque_nm  \
# ...

# %% [markdown]
# ##### This head function shows the first 5 observations of the dataset.

# %%
data.tail()
# Out:
#                         car_name  reviews_count fuel_type  \
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 198                 1991            4               5.0         Automatic
# 199                 1998            4               5.0         Automatic
# 200                 1956            4               7.0            Manual
# 201                 3998            8               5.0         Automatic
# 202                  796            3               5.0            Manual
#
#      fuel_tank_capacity  body_type  rating  starting_price  ending_price  \
# 198                 0.0  Hatchback     4.5          659000        999000
# ...

# %% [markdown]
# ##### This tail function shows the last 5 observations of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             203 non-null    object
#  1   reviews_count        203 non-null    int64
#  2   fuel_type            203 non-null    object
#  3   engine_displacement  203 non-null    int64
#  4   no_cylinder          203 non-null    int64
#  5   seating_capacity     202 non-null    float64
#  6   transmission_type    203 non-null    object
#  7   fuel_tank_capacity   203 non-null    float64
#  8   body_type            203 non-null    object
#  9   rating               203 non-null    float64
#  10  starting_price       203 non-null    int64
#  11  ending_price         203 non-null    int64
#  12  max_torque_nm        203 non-null    float64
#  13  max_torque_rpm       203 non-null    int64
#  14  max_power_bhp        203 non-null    float64
# ...

# %% [markdown]
# ##### This info function contains the dataset's information like the index,column of the dataset,and null and non null of the dataset and ithu contains the datatype of the dataset

# %%
data.describe()
# Out:
#        reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# count     203.000000           203.000000   203.000000        202.000000
# mean      118.684729          2305.921182     4.709360          5.014851
# std       314.331318          1493.837786     2.538664          1.161050
# min         1.000000             0.000000     0.000000          2.000000
# 25%         5.000000          1339.500000     4.000000          5.000000
# 50%        14.000000          1991.000000     4.000000          5.000000
# 75%        83.000000          2996.000000     6.000000          5.000000
# max      2392.000000          6750.000000    12.000000          8.000000
#
#        fuel_tank_capacity      rating  starting_price  ending_price  \
# count          203.000000  203.000000    2.030000e+02  2.030000e+02
# mean            46.143842    4.433498    9.443640e+06  1.112005e+07
# std             28.904207    0.280136    1.357035e+07  1.551746e+07
# ...

# %% [markdown]
# ##### This Describe function gives us a the statistical values of the dataset

# %%
data.shape
# Out:
# (203, 16)

# %% [markdown]
# ##### The shape command shows the shape of the dataset by the count of the observation and the variables

# %%
data.columns
# Out:
# Index(['car_name', 'reviews_count', 'fuel_type', 'engine_displacement',
#        'no_cylinder', 'seating_capacity', 'transmission_type',
#        'fuel_tank_capacity', 'body_type', 'rating', 'starting_price',
#        'ending_price', 'max_torque_nm', 'max_torque_rpm', 'max_power_bhp',
#        'max_power_rp'],
#       dtype='object')

# %% [markdown]
# ##### Column function is used to show the column names

# %%
data.shape
# Out:
# (203, 16)

# %% [markdown]
# ##### Shape function is used to display the observation and variables of the dataset

# %%
data.sort_values(["rating"],ascending=False)
# Out:
#                     car_name  reviews_count fuel_type  engine_displacement  \
# 160     Maserati GranTurismo              3    Petrol                 4691
# 139        Mercedes-Benz EQS              2  Electric                    0
# 176                 BMW X5 M             30    Petrol                 4395
# 181                 Lexus LX              1    Petrol                 5663
# 190  Mercedes-Benz GLC Coupe              5    Diesel                 1950
# ..                       ...            ...       ...                  ...
# 23               Hyundai i20            432    Petrol                  998
# 161       Ferrari F8 Tributo              6    Petrol                 3902
# 169     Aston Martin Vantage              3    Petrol                 3998
# 101           Datsun redi-GO             67    Petrol                  999
# 153          Maserati Ghibli              2    Petrol                 3799
#
# ...

# %% [markdown]
# ##### Sort_values is used to arranging it using the ascending function¶

# %%
data['depreciation']=data['starting_price']-data['ending_price']

# %% [markdown]
# ##### This function is used to add an another variable in the dataset

# %%
data
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %%
data['no_cylinder'].value_counts()
# Out:
# 4     96
# 8     29
# 3     26
# 6     25
# 0     16
# 12     8
# 5      1
# 1      1
# 10     1
# Name: no_cylinder, dtype: int64

# %% [markdown]
# ##### This value_count function is used to count the values in the Variables with their Data type and Int64

# %%
data_subset=data[['car_name','seating_capacity']]

# %% [markdown]
#  ##### This subset function is used to get the subset of the dataset

# %%
data_subset
# Out:
#                         car_name  seating_capacity
# 0                Maruti Alto K10               5.0
# 1                  Maruti Brezza               5.0
# 2                  Mahindra Thar               4.0
# 3                Mahindra XUV700               7.0
# 4             Mahindra Scorpio-N               7.0
# ..                           ...               ...
# 198     Mercedes-Benz AMG A 45 S               5.0
# 199  BMW 3 Series Gran Limousine               5.0
# 200               MG Hector Plus               7.0
# 201                   Audi RS Q8               5.0
# 202         Maruti Alto 800 tour               5.0
#
# [203 rows x 2 columns]

# %%
data_row=data[data['engine_displacement']>1000]

# %%
data_row
# Out:
#                         car_name  reviews_count fuel_type  \
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# 5                Toyota Fortuner             99    Diesel
# ..                           ...            ...       ...
# 197                Jeep Meridian             78    Diesel
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 1                   1462            4               5.0         Automatic
# 2                   2184            4               4.0         Automatic
# ...

# %%
data_index=data.set_index('car_name')

# %%
data_index
# Out:
#                              reviews_count fuel_type  engine_displacement  \
# car_name
# Maruti Alto K10                         51    Petrol                  998
# Maruti Brezza                           86    Petrol                 1462
# Mahindra Thar                          242    Diesel                 2184
# Mahindra XUV700                        313    Diesel                 2198
# Mahindra Scorpio-N                     107    Diesel                 2198
# ...                                    ...       ...                  ...
# Mercedes-Benz AMG A 45 S                35    Petrol                 1991
# BMW 3 Series Gran Limousine              3    Petrol                 1998
# MG Hector Plus                           2    Diesel                 1956
# Audi RS Q8                               9    Petrol                 3998
# Maruti Alto 800 tour                     4    Petrol                  796
#
# ...

# %% [markdown]
#  ##### This function is used for we can create a space to variable that we are going to assign

# %%
data_loc=data.loc[(data.rating>=2.5)&(data.fuel_type=='Petrol')]

# %%
data_loc
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 7                     Tata Punch            381    Petrol
# 9                   Maruti Swift            205    Petrol
# 11                 Hyundai Venue             36    Petrol
# ..                           ...            ...       ...
# 195            Honda City Hybrid              1    Petrol
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %% [markdown]
# ##### This function helps to locate a specific data in the dataset by using sample_loc function.

# %%
data_iloc=data.iloc[0:30,1:4]

# %%
data_iloc
# Out:
#     reviews_count fuel_type  engine_displacement
# 0              51    Petrol                  998
# 1              86    Petrol                 1462
# 2             242    Diesel                 2184
# 3             313    Diesel                 2198
# 4             107    Diesel                 2198
# 5              99    Diesel                 2755
# 6             731    Diesel                 1493
# 7             381    Petrol                 1199
# 8             107    Diesel                 1498
# 9             205    Petrol                 1197
# 10            568    Diesel                 1497
# 11             36    Petrol                  998
# 12           2171    Diesel                 1493
# 13              8    Diesel                 1997
# 14           2392    Diesel                 1956
# 15            137    Petrol                 1197
# 16             91    Diesel                 2393
# 17            110    Petrol                 1462
# ...

# %% [markdown]
# ##### This function is helps to display a specific number of observations and specific number of variables we use the sample_iloc function.

# %%
data_agg=data.groupby('car_name')['starting_price'].mean()

# %%
data_agg
# Out:
# car_name
# Aston Martin DBX        38200000.0
# Aston Martin Vantage     9950000.0
# Audi A4                  4312000.0
# Audi A6                  5999000.0
# Audi Q2                  3499000.0
#                            ...
# Volvo S60                4590000.0
# Volvo S90                6590000.0
# Volvo XC40               4450000.0
# Volvo XC60               6590000.0
# Volvo XC90               9390000.0
# Name: starting_price, Length: 199, dtype: float64

# %%
data.drop_duplicates(inplace=True)

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %%
data_index=data.reset_index()

# %%
data
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %% [markdown]
# ##### This function uses for sets a list of integer  from 0 to length of data as index.
